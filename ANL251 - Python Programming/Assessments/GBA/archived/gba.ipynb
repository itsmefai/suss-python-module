# %%
from datetime import datetime

class Plant:
    def __init__(self, filepath = 'myplants.txt'):
        self.filepath = filepath
        self.data = self.load_data()
    
    def load_data(self):
        f = open(self.filepath, "r")
        contents = f.read()

        # Creating a dictionary to store the plant's information
        plant_dict = {}

        for i in contents.split('\n\n'):
            plant_info = i.split('\n')
            plant_name = plant_info[0]

            plant_dict[plant_name] = {'Name': plant_name,
                                      'Last Update': plant_info[1],
                                      'Information': plant_info[2:-1]}
        
        return plant_dict
        
        # closing the text file
        f.close()
        
    def view_all(self):
        
        return self.data
    
    def add_plant(self, name):
        
        # datetime object containing current date and time
        now = datetime.now()

        # dd-mm-YY H:M:S
        dt_string = now.strftime("%d-%m-%Y %H:%M:%S")
        
        plant_info = []
        
        while True:
            info = input(f"Please enter the information for {name}. Key in 0 to exit: ")
            if info != '0':
                print("Information added")
                plant_info.append(info)
                continue
            else:
                #we're happy with the value given.
                #we're ready to exit the loop.
                print("Stop Editing ...")
                break

        self.data[name] = {'Name': name,
                          'Last Update': dt_string,
                          'Information': plant_info}
        
    
    def search(self, name):
        
        plants = list(self.data.keys())
        
        if name in plants:
            # if name is found
            for k, v in self.data[name].items():
                if k != 'Information':
                    print(f"{k}: {v}")
                else:
                    print(f"{k}:")
                    count = 1
                    for info in v:
                        print(f"({count}) {info}")
                        count += 1
            
        else:
            print('Flower not found!')
            print('Would you like to add the flower? Yes = 1, No = 0')
            while True:
                choice = input()
                if choice == '1':
                    self.add_plant(name)
                    print('Plant Added.')
                    break
                elif choice == '0':
                    print('Exiting...')
                    break
                else:
                    print('Invalid input. Try again.')
                    continue

# %%
a = Plant('myplants.txt')

# %%
a.view_all()
# Out:
# {'Monstera Deliciosa': {'Name': 'Monstera Deliciosa',
#   'Last Update': '2018-11-03 18:21:26',
#   'Information': ['Tropical/sub-Tropical plant',
#    'Leathery leaves, mid to dark green',
#    'Moist and well-draining soil',
#    'Semi-shade/full shade light requirements',
#    'Water only when top 2 inches of soil is dry',
#    'Intolerant to root rot']},
#  'Strelitzia Nicolai (White Birds of Paradise)': {'Name': 'Strelitzia Nicolai (White Birds of Paradise)',
#   'Last Update': '2018-11-05 10:12:15',
#   'Information': ['Semi-shade, full sun',
#    'Dark green leathery leaves',
#    'Like lots of water,but soil cannot be water-logged']},
#  'Alocasia Macrorrhizos': {'Name': 'Alocasia Macrorrhizos',
#   'Last Update': '2019-01-03 15:29:10',
#   'Information': ['Tropical asia',
#    'Moist and well-draining soil',
#    'Leaves and stem toxic upon ingestion',
#    'Semi-shade, full sun',
#    'Like lots of water, less susceptible to root rot']},
#  'Caladium White Christmas': {'Name': 'Caladium White Christmas',
#   'Last Update': '2020-03-07 10:10:20',
#   'Information': ['Partial sun to bright full shade',
#    'Direct sun might burn Leaves',
#    'Water regularly and never allow soil to dry out']},
#  'Sansevieria Trifasciata (Snake Plant)': {'Name': 'Sansevieria Trifasciata (Snake Plant)',
#   'Last Update': '2020-05-22 09:56:49',
#   'Information': ['Full shade to full sun',
#    'Well-draining soil',
#    'Water only when top 1 inch of soil is dry',
#    'Propagate by cuttings']}}

# %%
keys = list(a.data.keys())

for i in keys:
    for k, v in a.data[i].items():
                    if k != 'Information':
                        print(f"{k}: {v}")
                    else:
                        print(f"{k}:")
                        count = 1
                        for info in v:
                            print(f"({count}) {info}")
                            count += 1
# Out:
# Name: Monstera Deliciosa
# Last Update: 2018-11-03 18:21:26
# Information:
# (1) Tropical/sub-Tropical plant
# (2) Leathery leaves, mid to dark green
# (3) Moist and well-draining soil
# (4) Semi-shade/full shade light requirements
# (5) Water only when top 2 inches of soil is dry
# (6) Intolerant to root rot
# Name: Strelitzia Nicolai (White Birds of Paradise)
# Last Update: 2018-11-05 10:12:15
# Information:
# (1) Semi-shade, full sun
# (2) Dark green leathery leaves
# (3) Like lots of water,but soil cannot be water-logged
# Name: Alocasia Macrorrhizos
# Last Update: 2019-01-03 15:29:10
# Information:
# (1) Tropical asia
# (2) Moist and well-draining soil
# (3) Leaves and stem toxic upon ingestion
# (4) Semi-shade, full sun
# (5) Like lots of water, less susceptible to root rot
# Name: Caladium White Christmas
# Last Update: 2020-03-07 10:10:20
# Information:
# (1) Partial sun to bright full shade
# (2) Direct sun might burn Leaves
# (3) Water regularly and never allow soil to dry out
# Name: Sansevieria Trifasciata (Snake Plant)
# Last Update: 2020-05-22 09:56:49
# Information:
# (1) Full shade to full sun
# (2) Well-draining soil
# (3) Water only when top 1 inch of soil is dry
# (4) Propagate by cuttings
